# %% [markdown]
# Based off of Morgan's model file.

# %%
# IMPORTS!

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 200)

# %% [markdown]
# ### Read and clean data

# %%
air_walk = pd.read_csv('./data/air_walk_merged_clean.csv')
air_walk.head(2)
# Out:
#                            name  pm_2.5  temp_f                   model  \
# 0                #ValleyClimate   19.54    84.0  PMS5003+PMS5003+BME280
# 1  'S' St Between Inyo and Mono   18.52    93.0  PMS5003+PMS5003+BME280
#
#    hidden  flagged  downgraded  age  is_owner  1week_avg      fips_id  \
# 0   False    False       False    1     False      43.48  60190050003
# 1   False    False       False    1     False      41.81  60190005021
#
#    STATEFP  COUNTYFP  TRACTCE  BLKGRPCE    CSA                   CSA_Name  \
# 0        6        19     5000         3  260.0  Fresno-Madera-Hanford, CA
# 1        6        19      502         1  260.0  Fresno-Madera-Hanford, CA
#
#       CBSA   CBSA_Name  CBSA_POP  CBSA_EMP  CBSA_WRK    Ac_Total  Ac_Water  \
# 0  23420.0  Fresno, CA    978130    370040    371133  318.801501   3.41937
# 1  23420.0  Fresno, CA    978130    370040    371133  110.336080   0.00000
#
#       Ac_Land     Ac_Unpr  TotPop  CountHU     HH  P_WrkAge   Pct_AO0  \
# 0  315.382131  315.382131    1653    730.0  663.0     0.615  0.075415
# 1  110.336080  110.336080     953    408.0  381.0     0.599  0.081365
#
#     Pct_AO1  Pct_AO2p  Workers  R_LowWageWk  R_MedWageWk  R_HiWageWk  \
# 0  0.398190  0.526395      597          155          239         203
# 1  0.417323  0.501312      263           97          109          57
#
#    R_PCTLOWWAGE  TotEmp  E5_Ret  E5_Off  E5_Ind  E5_Svc  E5_Ent  E8_Ret  \
# 0      0.259631     972     152      59     185     362     214     152
# 1      0.368821    8559      58       0      47    7913     541      58
#
#    E8_off  E8_Ind  E8_Svc  E8_Ent  E8_Ed  E8_Hlth  E8_Pub  E_LowWageWk  \
# 0      59     185     326     214      0       36       0          383
# 1       0      47     157     541      7     7749       0          851
#
#    E_MedWageWk  E_HiWageWk  E_PctLowWage       D1A       D1B        D1C  \
# 0          395         194      0.394033  2.314652  5.241261   3.081975
# 1         2495        5213      0.099428  3.697793  8.637247  77.572087
#
#    D1C5_RET  D1C5_OFF  D1C5_IND   D1C5_SVC  D1C5_ENT  D1C8_RET  D1C8_OFF  \
# 0  0.481955  0.187075  0.586590   1.147814  0.678542  0.481955  0.187075
# 1  0.525667  0.000000  0.425971  71.717248  4.903201  0.525667  0.000000
#
#    D1C8_IND  D1C8_SVC  D1C8_ENT   D1C8_ED  D1C8_HLTH  D1C8_PUB        D1D  \
# 0  0.586590  1.033667  0.678542  0.000000   0.114147       0.0   5.396628
# 1  0.425971  1.422925  4.903201  0.063443  70.230880       0.0  81.269880
#
#     D2A_JPHH  D2B_E5MIX  D2B_E5MIXA  D2B_E8MIX  D2B_E8MIXA  D2A_EPHHM  \
# 0   1.466063   0.917728    0.917728   0.891662    0.768304   0.866894
# 1  22.464567   0.223268    0.192313   0.226667    0.195308   0.293581
#
#    D2C_TRPMX1  D2C_TRPMX2  D2C_TRIPEQ  D2R_JOBPOP  D2R_WRKEMP  D2A_WRKEMP  \
# 0    0.772433    0.830073    0.496555    0.740571    0.760994    0.614198
# 1    0.223464    0.246951    0.373636    0.200378    0.059624    0.030728
#
#    D2C_WREMLX        D3A     D3AAO     D3AMM      D3APO         D3B     D3BAO  \
# 0    0.679905  20.733482  0.000000  5.260424  15.473059   89.976435   0.00000
# 1    0.379359  25.092344  4.460549  6.869627  13.762167  102.505726  11.60092
#
#       D3BMM3     D3BMM4     D3BPO3     D3BPO4     D4A  D4B025  D4B050    D4C  \
# 0   4.058569  24.351411  30.439264  42.614970  513.65     0.0     0.0  11.00
# 1  34.802759  23.201839  58.004598  17.401379    0.00     0.0     0.0  15.33
#
#          D4D       D4E   D5AR   D5AE   D5BR   D5BE      D5CR     D5CRI  \
# 0  22.322127  0.006655  81753  73789  85266  54825  0.002845  0.922325
# 1  88.921049  0.016086  81602  71873  93553  65891  0.002840  0.920621
#
#        D5CE     D5CEI      D5DR     D5DRI      D5DE     D5DEI  D2A_Ranked  \
# 0  0.002718  0.943919  0.003773  0.586928  0.003201  0.500064          20
# 1  0.002647  0.919410  0.004140  0.643972  0.003847  0.600998           5
#
#    D2B_Ranked  D3B_Ranked  D4A_Ranked  NatWalkInd  Shape_Length    Shape_Area  \
# 0          18          13          15   15.666667   4825.986205  1.290175e+06
# 1           2          14          20   12.500000   3072.308296  4.465223e+05
#
#    Low_transit_flag_dist  Low_transit_flag_freq  Pct_Water  Pct_Land  \
# 0                  False                  False   0.010726  0.989274
# 1                  False                  False   0.000000  1.000000
#
#    Pct_Unpr  Log_Acres  log_TotPop  Pct_HH_occupied  log_D2A_JPHH  \
# 0  0.989274   5.767700    7.410952         0.908219      0.902623
# 1  1.000000   4.712553    6.860664         0.933824      3.155491
#
#    log_D2A_WRKEMP  Pct_Workers  pct_E5_Ret  pct_E5_Off  pct_E5_Ind  \
# 0        0.478838     0.361162    0.156379      0.0607    0.190329
# 1        0.030265     0.275971    0.006776      0.0000    0.005491
#
#    pct_E5_Svc  pct_E5_Ent  pct_E8_Ret  pct_E8_off  pct_E8_Ind  pct_E8_Svc  \
# 0    0.372428    0.220165    0.156379      0.0607    0.190329    0.335391
# 1    0.924524    0.063208    0.006776      0.0000    0.005491    0.018343
#
#    pct_E8_Ent  pct_E8_Ed  pct_E8_Hlth  pct_E8_Pub  log_D3AAO  log_D3AMM  \
# 0    0.220165   0.000000     0.037037         0.0   3.078854   0.000000
# 1    0.063208   0.000818     0.905363         0.0   3.261642   1.697549
#
#    log_D3APO   log_D3B  log_D3BAO  log_D3BMM3  log_D3BMM4  log_D3BPO3  \
# 0   1.834248  2.801726   4.510601     0.00000    1.621084    3.232834
# 1   2.063011  2.692068   4.639627     2.53377    3.578025    3.186429
#
#    log_D3BPO4   log_D4A   log_D4C   log_D4D   log_D4E   log_D5AE   log_D5BR  \
# 0    3.448058  3.775400  2.484907  3.149403  0.006633  11.208979  11.353543
# 1    4.077615  2.912426  2.793004  4.498932  0.015958  11.182670  11.446294
#
#     log_D5BE  log_D5CR  pow_D5CRI  pow_D5CE  pow_D5CEI  pow_D5DR  pow_D5DRI  \
# 0  10.911920  0.002841   0.991947  0.553883   0.994245  0.572362   0.948110
# 1  11.095772  0.002836   0.991763  0.552428   0.991633  0.577695   0.956944
#
#    pow_D5DE  pow_D5DEI  pow_D2A_Ranked  log_1week_avg
# 0  0.563022   0.933045        1.349283       3.795040
# 1  0.573469   0.950358        1.174619       3.756772

# %%
air_la = pd.read_csv('./data/air_walk_merged_clean_LA.csv')
air_la.head(2)
# Out:
#                     name  pm_2.5  temp_f                   model  hidden  \
# 0     003 FK Parking Lot    0.17   135.0  PMS5003+PMS5003+BME280   False
# 1  005- FK Shelby Forest    0.00    87.0  PMS5003+PMS5003+BME280   False
#
#    flagged  downgraded   age  is_owner  1week_avg      fips_id  STATEFP  \
# 0    False       False     0     False       8.93  60710008083        6
# 1    False       False  1297     False       0.01  60710008083        6
#
#    COUNTYFP  TRACTCE  BLKGRPCE    CSA                    CSA_Name     CBSA  \
# 0        71      808         3  348.0  Los Angeles-Long Beach, CA  40140.0
# 1        71      808         3  348.0  Los Angeles-Long Beach, CA  40140.0
#
#                               CBSA_Name  CBSA_POP  CBSA_EMP  CBSA_WRK  \
# 0  Riverside-San Bernardino-Ontario, CA   4518699   1439654   1749931
# 1  Riverside-San Bernardino-Ontario, CA   4518699   1439654   1749931
#
#     Ac_Total  Ac_Water    Ac_Land    Ac_Unpr  TotPop  CountHU     HH  \
# 0  102.68883       0.0  102.68883  102.68883    1356    380.0  359.0
# 1  102.68883       0.0  102.68883  102.68883    1356    380.0  359.0
#
#    P_WrkAge   Pct_AO0   Pct_AO1  Pct_AO2p  Workers  R_LowWageWk  R_MedWageWk  \
# 0     0.555  0.019499  0.306407  0.674095      448          117          136
# 1     0.555  0.019499  0.306407  0.674095      448          117          136
#
#    R_HiWageWk  R_PCTLOWWAGE  TotEmp  E5_Ret  E5_Off  E5_Ind  E5_Svc  E5_Ent  \
# 0         195      0.261161     585      44      14      14     421      92
# 1         195      0.261161     585      44      14      14     421      92
#
#    E8_Ret  E8_off  E8_Ind  E8_Svc  E8_Ent  E8_Ed  E8_Hlth  E8_Pub  \
# 0      44       9      14      77      92     61      283       5
# 1      44       9      14      77      92     61      283       5
#
#    E_LowWageWk  E_MedWageWk  E_HiWageWk  E_PctLowWage     D1A        D1B  \
# 0          150          216         219       0.25641  3.7005  13.204942
# 1          150          216         219       0.25641  3.7005  13.204942
#
#         D1C  D1C5_RET  D1C5_OFF  D1C5_IND  D1C5_SVC  D1C5_ENT  D1C8_RET  \
# 0  5.696822  0.428479  0.136334  0.136334  4.099764   0.89591  0.428479
# 1  5.696822  0.428479  0.136334  0.136334  4.099764   0.89591  0.428479
#
#    D1C8_OFF  D1C8_IND  D1C8_SVC  D1C8_ENT   D1C8_ED  D1C8_HLTH  D1C8_PUB  \
# 0  0.087643  0.136334  0.749838   0.89591  0.594028   2.755899  0.048691
# 1  0.087643  0.136334  0.749838   0.89591  0.594028   2.755899  0.048691
#
#         D1D  D2A_JPHH  D2B_E5MIX  D2B_E5MIXA  D2B_E8MIX  D2B_E8MIXA  \
# 0  9.397322  1.629526   0.559777    0.559777   0.737556    0.737556
# 1  9.397322  1.629526   0.559777    0.559777   0.737556    0.737556
#
#    D2A_EPHHM  D2C_TRPMX1  D2C_TRPMX2  D2C_TRIPEQ  D2R_JOBPOP  D2R_WRKEMP  \
# 0   0.682299    0.605275     0.66863    0.457875    0.602782    0.867377
# 1   0.682299    0.605275     0.66863    0.457875    0.602782    0.867377
#
#    D2A_WRKEMP  D2C_WREMLX        D3A  D3AAO     D3AMM      D3APO         D3B  \
# 0    0.765812    0.791213  27.206962    0.0  5.350424  21.856537  214.064958
# 1    0.765812    0.791213  27.206962    0.0  5.350424  21.856537  214.064958
#
#    D3BAO     D3BMM3     D3BMM4      D3BPO3     D3BPO4    D4A  D4B025  D4B050  \
# 0    0.0  68.556629  31.162104  186.972625  12.464842  551.2     0.0     0.0
# 1    0.0  68.556629  31.162104  186.972625  12.464842  551.2     0.0     0.0
#
#    D4C        D4D      D4E   D5AR   D5AE   D5BR   D5BE     D5CR     D5CRI  \
# 0  4.0  24.929683  0.00295  87557  86344  48836  29298  0.00068  0.568342
# 1  4.0  24.929683  0.00295  87557  86344  48836  29298  0.00068  0.568342
#
#        D5CE     D5CEI      D5DR     D5DRI     D5DE     D5DEI  D2A_Ranked  \
# 0  0.000635  0.603475  0.001306  0.080022  0.00086  0.086566          16
# 1  0.000635  0.603475  0.001306  0.080022  0.00086  0.086566          16
#
#    D2B_Ranked  D3B_Ranked  D4A_Ranked  NatWalkInd  Shape_Length   Shape_Area  \
# 0          17          19          15   16.833333   3002.787752  415575.8064
# 1          17          19          15   16.833333   3002.787752  415575.8064
#
#    Low_transit_flag_dist  Low_transit_flag_freq  Pct_Water  Pct_Land  \
# 0                  False                  False        0.0       1.0
# 1                  False                  False        0.0       1.0
#
#    Pct_Unpr  Log_Acres  log_TotPop  Pct_HH_occupied  log_D2A_JPHH  \
# 0       1.0   4.641394    7.213032         0.944737      0.966804
# 1       1.0   4.641394    7.213032         0.944737      0.966804
#
#    log_D2A_WRKEMP  Pct_Workers  pct_E5_Ret  pct_E5_Off  pct_E5_Ind  \
# 0        0.568611     0.330383    0.075214    0.023932    0.023932
# 1        0.568611     0.330383    0.075214    0.023932    0.023932
#
#    pct_E5_Svc  pct_E5_Ent  pct_E8_Ret  pct_E8_off  pct_E8_Ind  pct_E8_Svc  \
# 0    0.719658    0.157265    0.075214    0.015385    0.023932    0.131624
# 1    0.719658    0.157265    0.075214    0.015385    0.023932    0.131624
#
#    pct_E8_Ent  pct_E8_Ed  pct_E8_Hlth  pct_E8_Pub  log_D3AAO  log_D3AMM  \
# 0    0.157265   0.104274     0.483761    0.008547   3.339569        0.0
# 1    0.157265   0.104274     0.483761    0.008547   3.339569        0.0
#
#    log_D3APO   log_D3B  log_D3BAO  log_D3BMM3  log_D3BMM4  log_D3BPO3  \
# 0   1.848522  3.129237    5.37094         0.0    4.242141    3.470789
# 1   1.848522  3.129237    5.37094         0.0    4.242141    3.470789
#
#    log_D3BPO4   log_D4A   log_D4C   log_D4D   log_D4E   log_D5AE   log_D5BR  \
# 0    5.236296  2.600082  1.609438  3.255388  0.002946  11.366106  10.796244
# 1    5.236296  2.600082  1.609438  3.255388  0.002946  11.366106  10.796244
#
#     log_D5BE  log_D5CR  pow_D5CRI  pow_D5CE  pow_D5CEI  pow_D5DR  pow_D5DRI  \
# 0  10.285309  0.000679   0.945063  0.478952   0.950749  0.514757   0.776821
# 1  10.285309  0.000679   0.945063  0.478952   0.950749  0.514757   0.776821
#
#    pow_D5DE  pow_D5DEI  pow_D2A_Ranked  log_1week_avg
# 0  0.493659   0.782951        1.319508        2.29556
# 1  0.493659   0.782951        1.319508        0.00995

# %% [markdown]
# ##### Baseline Model

# %%
# Baseline model

from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

X_dum = air_walk[['NatWalkInd']]
y_dum = air_walk['1week_avg']

X_train, X_test, y_train, y_test = train_test_split(X_dum, y_dum, random_state=42)

dummy = DummyRegressor(strategy="mean")
dummy.fit(X_train, y_train)
preds_dum = dummy.predict(X_test)
print(dummy.score(X_test, y_test))
print(mean_squared_error(y_test, preds_dum, squared=False))
# Out:
# -0.000520466217100557
# 7.588526393381297

# %%
# More imports for modeling

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE, SequentialFeatureSelector
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Drop Location data and target variables

# %%
X = air_walk.select_dtypes(exclude=object).drop(
    columns = ['log_1week_avg', '1week_avg', 'pm_2.5', 'fips_id',
                'STATEFP', 'COUNTYFP', 'CSA', 'CBSA'])
X.isna().sum()[X.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
(X == float('inf')).sum()[(X == float('inf')).sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
X_la = air_la.select_dtypes(exclude=object).drop(
    columns = ['log_1week_avg', '1week_avg', 'pm_2.5', 
                'fips_id', 'STATEFP', 'COUNTYFP', 'CSA', 'CBSA',])

# %%
X.head()
# Out:
#    temp_f  hidden  flagged  downgraded  age  is_owner  TRACTCE  BLKGRPCE  \
# 0    84.0   False    False       False    1     False     5000         3
# 1    93.0   False    False       False    1     False      502         1
# 2    81.0   False    False       False    1     False   608900         3
# 3    88.0   False    False       False    1     False   608900         3
# 4   135.0   False    False       False    0     False      808         3
#
#    CBSA_POP  CBSA_EMP  CBSA_WRK    Ac_Total  Ac_Water     Ac_Land     Ac_Unpr  \
# 0    978130    370040    371133  318.801501  3.419370  315.382131  315.382131
# 1    978130    370040    371133  110.336080  0.000000  110.336080  110.336080
# 2   4673221   2400290   2241034  193.896652  2.719336  191.177316  165.061400
# 3   4673221   2400290   2241034  193.896652  2.719336  191.177316  165.061400
# 4   4518699   1439654   1749931  102.688830  0.000000  102.688830  102.688830
#
#    TotPop  CountHU      HH  P_WrkAge   Pct_AO0   Pct_AO1  Pct_AO2p  Workers  \
# 0    1653    730.0   663.0     0.615  0.075415  0.398190  0.526395      597
# 1     953    408.0   381.0     0.599  0.081365  0.417323  0.501312      263
# 2    3225   1517.0  1406.0     0.574  0.135846  0.366287  0.497866     1404
# 3    3225   1517.0  1406.0     0.574  0.135846  0.366287  0.497866     1404
# 4    1356    380.0   359.0     0.555  0.019499  0.306407  0.674095      448
#
#    R_LowWageWk  R_MedWageWk  R_HiWageWk  R_PCTLOWWAGE  TotEmp  E5_Ret  E5_Off  \
# 0          155          239         203      0.259631     972     152      59
# 1           97          109          57      0.368821    8559      58       0
# 2          194          212         998      0.138177     346       5     103
# 3          194          212         998      0.138177     346       5     103
# 4          117          136         195      0.261161     585      44      14
#
#    E5_Ind  E5_Svc  E5_Ent  E8_Ret  E8_off  E8_Ind  E8_Svc  E8_Ent  E8_Ed  \
# 0     185     362     214     152      59     185     326     214      0
# 1      47    7913     541      58       0      47     157     541      7
# 2      15     212      11       5     103      15      20      11    161
# 3      15     212      11       5     103      15      20      11    161
# 4      14     421      92      44       9      14      77      92     61
#
#    E8_Hlth  E8_Pub  E_LowWageWk  E_MedWageWk  E_HiWageWk  E_PctLowWage  \
# 0       36       0          383          395         194      0.394033
# 1     7749       0          851         2495        5213      0.099428
# 2       31       0           76           73         197      0.219653
# 3       31       0           76           73         197      0.219653
# 4      283       5          150          216         219      0.256410
#
#         D1A        D1B        D1C  D1C5_RET  D1C5_OFF  D1C5_IND   D1C5_SVC  \
# 0  2.314652   5.241261   3.081975  0.481955  0.187075  0.586590   1.147814
# 1  3.697793   8.637247  77.572087  0.525667  0.000000  0.425971  71.717248
# 2  9.190519  19.538184   2.096190  0.030292  0.624010  0.090875   1.284371
# 3  9.190519  19.538184   2.096190  0.030292  0.624010  0.090875   1.284371
# 4  3.700500  13.204942   5.696822  0.428479  0.136334  0.136334   4.099764
#
#    D1C5_ENT  D1C8_RET  D1C8_OFF  D1C8_IND  D1C8_SVC  D1C8_ENT   D1C8_ED  \
# 0  0.678542  0.481955  0.187075  0.586590  1.033667  0.678542  0.000000
# 1  4.903201  0.525667  0.000000  0.425971  1.422925  4.903201  0.063443
# 2  0.066642  0.030292  0.624010  0.090875  0.121167  0.066642  0.975395
# 3  0.066642  0.030292  0.624010  0.090875  0.121167  0.066642  0.975395
# 4  0.895910  0.428479  0.087643  0.136334  0.749838  0.895910  0.594028
#
#    D1C8_HLTH  D1C8_PUB        D1D   D2A_JPHH  D2B_E5MIX  D2B_E5MIXA  \
# 0   0.114147  0.000000   5.396628   1.466063   0.917728    0.917728
# 1  70.230880  0.000000  81.269880  22.464567   0.223268    0.192313
# 2   0.187809  0.000000  11.286709   0.246088   0.601312    0.601312
# 3   0.187809  0.000000  11.286709   0.246088   0.601312    0.601312
# 4   2.755899  0.048691   9.397322   1.629526   0.559777    0.559777
#
#    D2B_E8MIX  D2B_E8MIXA  D2A_EPHHM  D2C_TRPMX1  D2C_TRPMX2  D2C_TRIPEQ  \
# 0   0.891662    0.768304   0.866894    0.772433    0.830073    0.496555
# 1   0.226667    0.195308   0.293581    0.223464    0.246951    0.373636
# 2   0.721792    0.675442   0.383994    0.444501    0.489292    0.345147
# 3   0.721792    0.675442   0.383994    0.444501    0.489292    0.345147
# 4   0.737556    0.737556   0.682299    0.605275    0.668630    0.457875
#
#    D2R_JOBPOP  D2R_WRKEMP  D2A_WRKEMP  D2C_WREMLX        D3A     D3AAO  \
# 0    0.740571    0.760994    0.614198    0.679905  20.733482  0.000000
# 1    0.200378    0.059624    0.030728    0.379359  25.092344  4.460549
# 2    0.193783    0.395429    4.057803    0.046991  22.265551  0.000000
# 3    0.193783    0.395429    4.057803    0.046991  22.265551  0.000000
# 4    0.602782    0.867377    0.765812    0.791213  27.206962  0.000000
#
#       D3AMM      D3APO         D3B     D3BAO     D3BMM3     D3BMM4  \
# 0  5.260424  15.473059   89.976435   0.00000   4.058569  24.351411
# 1  6.869627  13.762167  102.505726  11.60092  34.802759  23.201839
# 2  7.109057  15.156494   93.778490   0.00000  13.390710   6.695355
# 3  7.109057  15.156494   93.778490   0.00000  13.390710   6.695355
# 4  5.350424  21.856537  214.064958   0.00000  68.556629  31.162104
#
#        D3BPO3     D3BPO4      D4A  D4B025  D4B050    D4C        D4D       D4E  \
# 0   30.439264  42.614970   513.65     0.0     0.0  11.00  22.322127  0.006655
# 1   58.004598  17.401379     0.00     0.0     0.0  15.33  88.921049  0.016086
# 2  117.168712   0.000000  2000.00     0.0     0.0   0.00   0.000000  0.000000
# 3  117.168712   0.000000  2000.00     0.0     0.0   0.00   0.000000  0.000000
# 4  186.972625  12.464842   551.20     0.0     0.0   4.00  24.929683  0.002950
#
#     D5AR   D5AE   D5BR   D5BE      D5CR     D5CRI      D5CE     D5CEI  \
# 0  81753  73789  85266  54825  0.002845  0.922325  0.002718  0.943919
# 1  81602  71873  93553  65891  0.002840  0.920621  0.002647  0.919410
# 2  95811  75432      0      0  0.000283  0.345220  0.000271  0.383653
# 3  95811  75432      0      0  0.000283  0.345220  0.000271  0.383653
# 4  87557  86344  48836  29298  0.000680  0.568342  0.000635  0.603475
#
#        D5DR     D5DRI      D5DE     D5DEI  D2A_Ranked  D2B_Ranked  D3B_Ranked  \
# 0  0.003773  0.586928  0.003201  0.500064          20          18          13
# 1  0.004140  0.643972  0.003847  0.600998           5           2          14
# 2  0.000000  0.000000  0.000000  0.000000           7          15          14
# 3  0.000000  0.000000  0.000000  0.000000           7          15          14
# 4  0.001306  0.080022  0.000860  0.086566          16          17          19
#
#    D4A_Ranked  NatWalkInd  Shape_Length    Shape_Area  Low_transit_flag_dist  \
# 0          15   15.666667   4825.986205  1.290175e+06                  False
# 1          20   12.500000   3072.308296  4.465223e+05                  False
# 2           1    8.666667   6296.012985  7.846879e+05                   True
# 3           1    8.666667   6296.012985  7.846879e+05                   True
# 4          15   16.833333   3002.787752  4.155758e+05                  False
#
#    Low_transit_flag_freq  Pct_Water  Pct_Land  Pct_Unpr  Log_Acres  \
# 0                  False   0.010726  0.989274  0.989274   5.767700
# 1                  False   0.000000  1.000000  1.000000   4.712553
# 2                   True   0.014025  0.985975  0.851285   5.272469
# 3                   True   0.014025  0.985975  0.851285   5.272469
# 4                  False   0.000000  1.000000  1.000000   4.641394
#
#    log_TotPop  Pct_HH_occupied  log_D2A_JPHH  log_D2A_WRKEMP  Pct_Workers  \
# 0    7.410952         0.908219      0.902623        0.478838     0.361162
# 1    6.860664         0.933824      3.155491        0.030265     0.275971
# 2    8.078998         0.926829      0.220009        1.620932     0.435349
# 3    8.078998         0.926829      0.220009        1.620932     0.435349
# 4    7.213032         0.944737      0.966804        0.568611     0.330383
#
#    pct_E5_Ret  pct_E5_Off  pct_E5_Ind  pct_E5_Svc  pct_E5_Ent  pct_E8_Ret  \
# 0    0.156379    0.060700    0.190329    0.372428    0.220165    0.156379
# 1    0.006776    0.000000    0.005491    0.924524    0.063208    0.006776
# 2    0.014451    0.297688    0.043353    0.612717    0.031792    0.014451
# 3    0.014451    0.297688    0.043353    0.612717    0.031792    0.014451
# 4    0.075214    0.023932    0.023932    0.719658    0.157265    0.075214
#
#    pct_E8_off  pct_E8_Ind  pct_E8_Svc  pct_E8_Ent  pct_E8_Ed  pct_E8_Hlth  \
# 0    0.060700    0.190329    0.335391    0.220165   0.000000     0.037037
# 1    0.000000    0.005491    0.018343    0.063208   0.000818     0.905363
# 2    0.297688    0.043353    0.057803    0.031792   0.465318     0.089595
# 3    0.297688    0.043353    0.057803    0.031792   0.465318     0.089595
# 4    0.015385    0.023932    0.131624    0.157265   0.104274     0.483761
#
#    pct_E8_Pub  log_D3AAO  log_D3AMM  log_D3APO   log_D3B  log_D3BAO  \
# 0    0.000000   3.078854   0.000000   1.834248  2.801726   4.510601
# 1    0.000000   3.261642   1.697549   2.063011  2.692068   4.639627
# 2    0.000000   3.146974   0.000000   2.092982  2.782322   4.551542
# 3    0.000000   3.146974   0.000000   2.092982  2.782322   4.551542
# 4    0.008547   3.339569   0.000000   1.848522  3.129237   5.370940
#
#    log_D3BMM3  log_D3BMM4  log_D3BPO3  log_D3BPO4   log_D4A   log_D4C  \
# 0     0.00000    1.621084    3.232834    3.448058  3.775400  2.484907
# 1     2.53377    3.578025    3.186429    4.077615  2.912426  2.793004
# 2     0.00000    2.666583    2.040617    4.772113  0.000000  0.000000
# 3     0.00000    2.666583    2.040617    4.772113  0.000000  0.000000
# 4     0.00000    4.242141    3.470789    5.236296  2.600082  1.609438
#
#     log_D4D   log_D4E   log_D5AE   log_D5BR   log_D5BE  log_D5CR  pow_D5CRI  \
# 0  3.149403  0.006633  11.208979  11.353543  10.911920  0.002841   0.991947
# 1  4.498932  0.015958  11.182670  11.446294  11.095772  0.002836   0.991763
# 2  0.000000  0.000000  11.231000   0.000000   0.000000  0.000283   0.899103
# 3  0.000000  0.000000  11.231000   0.000000   0.000000  0.000283   0.899103
# 4  3.255388  0.002946  11.366106  10.796244  10.285309  0.000679   0.945063
#
#    pow_D5CE  pow_D5CEI  pow_D5DR  pow_D5DRI  pow_D5DE  pow_D5DEI  \
# 0  0.553883   0.994245  0.572362   0.948110  0.563022   0.933045
# 1  0.552428   0.991633  0.577695   0.956944  0.573469   0.950358
# 2  0.439787   0.908644  0.000000   0.000000  0.000000   0.000000
# 3  0.439787   0.908644  0.000000   0.000000  0.000000   0.000000
# 4  0.478952   0.950749  0.514757   0.776821  0.493659   0.782951
#
#    pow_D2A_Ranked
# 0        1.349283
# 1        1.174619
# 2        1.214814
# 3        1.214814
# 4        1.319508

# %% [markdown]
# ### Models

# %%
def model_run(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    print("train score: ", model.score(X_train, y_train))
    print("test score: ", model.score(X_test, y_test))
    print("rmse: ", mean_squared_error(y_test, preds, squared = False))

# %%
y = air_walk['log_1week_avg']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# #### Linear Regression with RFE

# %%
pipe1 = make_pipeline(
    StandardScaler(), 
    RFE(estimator=LinearRegression(), n_features_to_select=8),
    LinearRegression()
)

model_run(pipe1, X_train, X_test, y_train, y_test)
# Out:
# train score:  0.038820169384541914
# test score:  0.046514984296775475
# rmse:  0.6927246307535777

# %% [markdown]
# Top columns - none of these columns are highly correlated with target

# %%
X.columns[pipe1.named_steps['rfe'].get_support()]
# Out:
# Index(['Workers', 'R_HiWageWk', 'E5_Off', 'E8_off', 'E8_Pub', 'pct_E5_Off',
#        'pct_E8_off', 'pct_E8_Pub'],
#       dtype='object')

# %% [markdown]
# #### Linear Regression with SFS

# %%
pipe2 = make_pipeline(
    # StandardScaler(), # Not needed for unregularized linear regression
    SequentialFeatureSelector(estimator=LinearRegression(), n_features_to_select=8),
    LinearRegression()
)

model_run(pipe2, X_train, X_test, y_train, y_test)
# Out:
# train score:  0.2838774682345975
# test score:  0.26796958843317675
# rmse:  0.6069714385812478

# %%
pipe2.named_steps['sequentialfeatureselector'].get_feature_names_out()
# Out:
# array(['temp_f', 'CBSA_POP', 'CBSA_EMP', 'Pct_AO2p', 'Log_Acres',
#        'Pct_HH_occupied', 'log_D5AE', 'pow_D5CE'], dtype=object)

# %%
features = X.columns[pipe2.named_steps['sequentialfeatureselector'].get_support()]
features
# Out:
# Index(['temp_f', 'CBSA_POP', 'CBSA_EMP', 'Pct_AO2p', 'Log_Acres',
#        'Pct_HH_occupied', 'log_D5AE', 'pow_D5CE'],
#       dtype='object')

# %% [markdown]
# #### Top features only

# %%
X1 = X[['log_D5AE', 'log_D3AAO', 'Pct_HH_occupied', 'log_D4A', 'Pct_Unpr',
        'Log_Acres', 'Shape_Length', 'R_PCTLOWWAGE', 'Low_transit_flag_dist']]

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y, random_state=42)

plt.figure(figsize = (8, 8))
sns.heatmap(pd.concat([X1, y], axis = 1, join = 'inner').corr(), 
            annot = True, cmap = 'RdYlBu_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# SFS is superior to taking only the features with the strongest correlations to target.

# %%
pipe_lr = make_pipeline(
    StandardScaler(),
    LinearRegression()
)

model_run(pipe_lr, X1_train, X1_test, y1_train, y1_test)
# Out:
# train score:  0.22446149710113028
# test score:  0.22912320695501787
# rmse:  0.6228682294560756

# %% [markdown]
# ### LA dataset models

# %%
y_la = air_la['log_1week_avg']
X_train_la, X_test_la, y_train_la, y_test_la = train_test_split(X_la, y_la, random_state = 42)

# %%
from sklearn.base import clone
pipe2_la = clone(pipe2)
# pipe2_la.set_params(sequentialfeatureselector__n_features_to_select = 7)

# %%
model_run(pipe2_la, X_train_la, X_test_la, y_train_la, y_test_la)
# Out:
# train score:  0.4863640419227081
# test score:  0.3678428566161428
# rmse:  0.5027720352035986

# %%
features_la = X_la.columns[pipe2_la.named_steps['sequentialfeatureselector'].get_support()]
features_la
# Out:
# Index(['Pct_AO2p', 'E5_Ind', 'D1C5_OFF', 'D5AR', 'D5AE', 'Log_Acres',
#        'pct_E5_Off', 'log_D5AE'],
#       dtype='object')

# %% [markdown]
# ### Model coefficients

# %% [markdown]
# All data

# %%
pd.DataFrame({'coef': pipe2.named_steps['linearregression'].coef_},
              index =  features)
# Out:
#                          coef
# temp_f           9.738277e-03
# CBSA_POP        -3.334473e-07
# CBSA_EMP         5.841282e-07
# Pct_AO2p        -3.340779e-01
# Log_Acres       -4.956099e-02
# Pct_HH_occupied  5.724298e-01
# log_D5AE         1.241778e-01
# pow_D5CE        -7.108496e-01

# %% [markdown]
# LA

# %%
pd.DataFrame({'coef': pipe2_la.named_steps['linearregression'].coef_},
              index =  features_la)
# Out:
#                 coef
# Pct_AO2p   -0.343512
# E5_Ind      0.000064
# D1C5_OFF   -0.013499
# D5AR       -0.000005
# D5AE        0.000007
# Log_Acres  -0.086268
# pct_E5_Off  0.616272
# log_D5AE    0.078319

# %% [markdown]
# #### Multicollinearity check

# %%
plt.figure(figsize = (9, 9))
sns.heatmap(pd.concat([X[features], y], axis = 1, join = 'inner').corr(), 
            annot = True, cmap = 'RdYlBu_r')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (8, 8))
sns.heatmap(pd.concat([X_la[features_la], y], axis = 1, join = 'inner').corr(), 
            annot = True, cmap = 'RdYlBu_r')
# Out:
# <AxesSubplot:>

# %%
X[['CBSA_POP', 'CBSA_EMP']].corr()
# Out:
#           CBSA_POP  CBSA_EMP
# CBSA_POP  1.000000  0.995565
# CBSA_EMP  0.995565  1.000000

# %%
X[['D5AR', 'D5AE']].corr()
# Out:
#           D5AR      D5AE
# D5AR  1.000000  0.988722
# D5AE  0.988722  1.000000

# %% [markdown]
# #### Drop correlated inputs

# %%
features_decorr = features.drop('CBSA_EMP') # correlated to CBSA_POP

# %%
features_la_decorr = features_la.drop(['D5AE', 'D5AR']) # both correlated to log_D5AE
features_la_decorr = features_la_decorr.drop(['D1C5_OFF']) # correlated to pct_E5_OFF

# %%
lr = LinearRegression()

model_run(lr, X_train[features_decorr], X_test[features_decorr], 
          y_train, y_test)
# Out:
# train score:  0.26902897995276054
# test score:  0.24629349700067882
# rmse:  0.615892371405338

# %%
pd.DataFrame({'coef': lr.coef_}, index =  features_decorr)
# Out:
#                          coef
# temp_f           8.302439e-03
# CBSA_POP        -5.989267e-08
# Pct_AO2p        -2.872118e-01
# Log_Acres       -5.537839e-02
# Pct_HH_occupied  6.311089e-01
# log_D5AE         1.387315e-01
# pow_D5CE        -8.650281e-01

# %%
lr_la = LinearRegression()

model_run(lr_la, X_train_la[features_la_decorr], X_test_la[features_la_decorr], 
          y_train_la, y_test_la)
# Out:
# train score:  0.4420466828873887
# test score:  0.33651993930744883
# rmse:  0.515077437752319

# %%
pd.DataFrame({'coef': lr_la.coef_}, index =  features_la_decorr)
# Out:
#                 coef
# Pct_AO2p   -0.406770
# E5_Ind      0.000055
# Log_Acres  -0.084928
# pct_E5_Off  0.322075
# log_D5AE    0.172058
